# %% [markdown]
# TP01 \- Deepnote velasquez katherine

# %% [markdown]
# Mi nombre es Katherine, tengo 24 años\.

# %% [markdown]
# Tengo un emprendimiento de ropa streetwear anime y me encanta todo lo relacionado al analisis de datos\.
# Espero que esta materia me permita comprender mejor cómo se desarrollan e implementan sistemas de Inteligencia Artificial en situaciones reales\. Me interesa aprender no solo la parte teórica, sino también adquirir herramientas prácticas para poder crear y aplicar soluciones utilizando IA\.

# %%
print("Mi primer notebook en Deepnote")
# Out:
# Mi primer notebook en Deepnote

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6e60f776-fc23-40de-821a-7e1e2c46d7e8' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
