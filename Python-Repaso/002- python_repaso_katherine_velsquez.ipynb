# %% [markdown]
# # TP 02 \- Introducción a Python

# %% [markdown]
# Katherine velasquez

# %%
nombre = "katherine"
edad = 24
ciudad = "villa lugano"
print("Hola mi nombre es", nombre, "tengo", edad, "años y vivo en", ciudad)

a = 20
b = 2

suma = a + b
resta = a - b
multiplicacion = b * a
division = a / b

print("Suma:", a + b)
print("Resta:", a - b)
print("Multiplicación:", a * b)
print("División:", a / b)

print("-------------------------------------------------")

edad= int(input( "ingrese su edad"))
if edad >= 18:
    print("eres mayor de edad")
else:
    print("eres menor de edad")

print("-------------------------------------------------")
print("Lista de numeros")
lista = [20,10,15,9]

for numero in lista:
    print(numero)

suma = sum(lista)
promedio = suma / len(lista)

print("Suma total:", suma)
print("Promedio:", promedio)
# Out:
# Hola mi nombre es katherine tengo 24 años y vivo en villa lugano
# Suma: 22
# Resta: 18
# Multiplicación: 40
# División: 10.0
# -------------------------------------------------
# eres menor de edad
# -------------------------------------------------
# Lista de numeros
# 20
# 10
# 15
# 9
# Suma total: 54
# Promedio: 13.5

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6e60f776-fc23-40de-821a-7e1e2c46d7e8' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
